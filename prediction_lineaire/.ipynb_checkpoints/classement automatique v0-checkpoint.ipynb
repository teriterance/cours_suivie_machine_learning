# %% [markdown]
# ### Classez automatiquement des feuilles d’arbre

# %% [markdown]
# Lien vers l'exercice:
# http://exercices.openclassrooms.com/assessment/644?id=4444646&slug=entrainez-un-modele-predictif-lineaire&login=784&tk=286e6b0631df3179188cb3e1cc27f165&sbd=2016-02-01&sbdtk=2466d6bae51e373d89ac8e3f74213199

# %%
import pandas as pd
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_colwidth', -1)

# %%
train = pd.read_csv('Dataset_feuilles_1.csv')
test = pd.read_csv('test.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-c815e7b5c918> in <module>
# ----> 1 train = pd.read_csv('Dataset_feuilles_1.csv')
#       2 test = pd.read_csv('test.csv')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
train.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0  1   Acer_Opalus            0.007812  0.023438  0.023438  0.003906
# 1  2   Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2  3   Quercus_Hartwissiana   0.005859  0.009766  0.019531  0.007812
# 3  5   Tilia_Tomentosa        0.000000  0.003906  0.023438  0.005859
# 4  6   Quercus_Variabilis     0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8   margin9  margin10  margin11  \
# 0  0.011719  0.009766  0.027344  0.0      0.001953  0.033203  0.013672
# 1  0.025391  0.001953  0.019531  0.0      0.000000  0.007812  0.003906
# 2  0.003906  0.005859  0.068359  0.0      0.000000  0.044922  0.007812
# 3  0.021484  0.019531  0.023438  0.0      0.013672  0.017578  0.001953
# 4  0.013672  0.015625  0.005859  0.0      0.000000  0.005859  0.001953
#
#    margin12  margin13  margin14  margin15  margin16  margin17  margin18  \
# ...

# %%
test.head()
# Out:
#    id   margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0  4   0.019531  0.009766  0.078125  0.011719  0.003906  0.015625  0.005859
# 1  7   0.007812  0.005859  0.064453  0.009766  0.003906  0.013672  0.007812
# 2  9   0.000000  0.000000  0.001953  0.021484  0.041016  0.000000  0.023438
# 3  12  0.000000  0.000000  0.009766  0.011719  0.017578  0.000000  0.003906
# 4  13  0.001953  0.000000  0.015625  0.009766  0.039062  0.000000  0.009766
#
#    margin8   margin9  margin10  margin11  margin12  margin13  margin14  \
# 0  0.0      0.005859  0.023438  0.005859  0.021484  0.076172  0.001953
# 1  0.0      0.033203  0.023438  0.009766  0.019531  0.039062  0.027344
# 2  0.0      0.011719  0.005859  0.001953  0.021484  0.001953  0.019531
# 3  0.0      0.003906  0.001953  0.000000  0.029297  0.000000  0.039062
# 4  0.0      0.005859  0.000000  0.001953  0.033203  0.000000  0.003906
#
#    margin15  margin16  margin17  margin18  margin19  margin20  margin21  \
# ...

# %%
train.shape
# Out:
# (990, 194)

# %%
train.species.nunique()
# Out:
# 99

# %%
test.dtypes
# Out:
# id           int64
# margin1      float64
# margin2      float64
# margin3      float64
# margin4      float64
# margin5      float64
# margin6      float64
# margin7      float64
# margin8      float64
# margin9      float64
# margin10     float64
# margin11     float64
# margin12     float64
# margin13     float64
# margin14     float64
# margin15     float64
# margin16     float64
# margin17     float64
# margin18     float64
# margin19     float64
# margin20     float64
# margin21     float64
# margin22     float64
# margin23     float64
# margin24     float64
# margin25     float64
# margin26     float64
# margin27     float64
# margin28     float64
# margin29     float64
# margin30     float64
# margin31     float64
# margin32     float64
# margin33     float64
# margin34     float64
# margin35     float64
# margin36     float64
# margin37     float64
# margin38     float64
# margin39     float64
# margin40     float64
# margin41     float64
# margin42     float64
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import numpy as np

# %%
X_train, X_test, y_train, y_test = train_test_split(train.iloc[:, 2:], train['species'], test_size=0.25)

# %% [markdown]
# ### Baseline de performance

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_predict_knn = knn.predict(X_test)

# %%
result_knn = (y_test == y_predict_knn).sum()/len(y_predict)*100
print(result_knn)
# Out:
# 83.06451612903226

# %% [markdown]
# ### SVM Multiclasse

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
svm = SVC()
C = np.logspace(-5, 5, 16)
degree = [3,4,5]

params = {'C' : C,
         'degree' : degree}

gs_svm = GridSearchCV(svm, params, gamma='auto', cv=10)
gs_svm.fit(X_train, y_train)

print(gs_svm.best_params_)
# Out:
# C:\Users\Vincent\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:657: Warning: The least populated class in y has only 5 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# C:\Users\Vincent\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Vincent\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
y_predict_svm = gs_svm.predict(X_test)

# %%
result_svm =  (y_predict_svm==y_test).sum()/len(y_predict)*100
print(result_svm)
# Out:
# 95.96774193548387

# %% [markdown]
# ### Critique / Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
scores = pd.DataFrame(gs_svm.cv_results_)

# %%
plt.figure(figsize = (20,10))
plt.xscale('log')
plt.title('Comparaison des paramètres vis à vis du score obtenu')
sns.scatterplot(x = scores['param_C'], y=scores['mean_test_score'], hue = scores['param_degree'].astype('int32'))

# %%
sns.barplot(x=['KNN', 'SVM avec paramètres optimaux'], y=[result_knn, result_svm])
plt.title('Taux de projection juste')
plt.show()

# %% [markdown]
# ### Modèle final

# %% [markdown]
# On retiendra le svm avec C=4641.588833612773 et degree=3
